# %%
from bs4 import BeautifulSoup
import requests
import lxml
import time
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
# actual URL for our website
url = "https://enbek.kz/kk/search/vacancy?except[subsidized]=subsidized&languages[00000%2446%D0%90%D0%9D%D0%93%D0%9B]=00000%2446%D0%90%D0%9D%D0%93%D0%9B&languages[00000%2446%D0%9A%D0%90%D0%97]=00000%2446%D0%9A%D0%90%D0%97"

# for website to not think that we are some kind of bot
headers = {
    "accept": "*/*",
    "user-agent":  "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/130.0.0.0 Safari/537.36"
}

# To store the attributes into these lists
titles = []
fields = []
salaries = []
locations = []
cities = []
experiences = []
enrollment_statuses = []
educations = []
dates = []

# method for web scraping
def scraping_page(url):
    # Requests
    req = requests.get(url, headers = headers)
    src = req.text

    # Now we can start doing our scraping
    soup = BeautifulSoup(src, "lxml")

    # Our essential info is in this class
    jobs = soup.find(class_="row").find_all(class_="item-list")




    # With loops because we got a lot of info to pull
    for jobs in jobs:

        #Because there might not be an info, therefore, we use exceptions
        try:
            title = jobs.find(class_="me-1").find("a",class_="stretched").text.strip()
        except AttributeError:
            title = np.nan

        try:
            field = jobs.find(class_="profobl").find("span").text.strip()
        except AttributeError:
            field = np.nan

        try:
            salary = jobs.find(class_="price").text.strip()
        except AttributeError:
            salary = np.nan

        try:
            location = jobs.find("li", class_="company d-flex align-items-center is-valid").text.strip()
        except AttributeError:
            location = np.nan

        try: 
            city = jobs.find("li", class_="location d-flex align-items-center me-lg-3").text.strip()
        except AttributeError:
            city = np.nan

        try:
            experience = jobs.find("li", class_="experience d-flex align-items-center").text.strip()
        except AttributeError:
            experience = np.nan

        try: 
            enrollment_status = jobs.find("li", class_="time d-flex align-items-center me-lg-3").text.strip()
        except AttributeError:
            enrollment_status = np.nan

        try:
            education = jobs.find("li", class_="education d-flex align-items-center").text.strip()
        except AttributeError:
            education = np.nan

        try:
            date = jobs.find("div", class_="right-content ms-lg-auto").find("span").text.strip()
        except AttributeError:
            date = np.nan


        # Now we store our info into previous lists by order
        titles.append(title)
        fields.append(field)
        salaries.append(salary)
        locations.append(location)
        cities.append(city)
        experiences.append(experience)
        enrollment_statuses.append(enrollment_status)
        educations.append(education)
        dates.append(date)


# Due to having a lot of pages, we have to do them one-by-one, by calling our method
for page_num in range(1, 32):
    #We can just add page number at the end
    page_url = f"{url}&page={page_num}"
    scraping_page(page_url)
    # It is essential to wait some time before actions, because a website may restrict its access
    time.sleep(2)

# %%
# Transforming data to DataFrame and saving it to csv 
data = pd.DataFrame({
    'Titles': titles,
    'Fields': fields,
    'Salaries': salaries,
    'Locations': locations,
    'Cities': cities,
    'Experiences': experiences,
    'Enrollment_statuses': enrollment_statuses,
    'Educations': educations,
    'Dates': dates
})

data.to_csv('enbek.csv', index=False)

# %%
# Load raw data
data = pd.read_csv('enbek.csv')

# Check for missing values
print(data.isnull().sum())

# If salary is null then we can assume that it does not pay
data['Salaries'].fillna(0,inplace = True)
# If education is null then we can assume that it does not any education
data['Educations'].fillna('Any',inplace = True)
# If field is null then we can assume that it does not fit any field
data['Fields'].fillna('No Field',inplace = True)
data['Enrollment_statuses'].fillna('Unknown',inplace = True)
# Out:
# Titles                 0
# Fields                 4
# Salaries               5
# Locations              0
# Cities                 0
# Experiences            0
# Enrollment_statuses    5
# Educations             1
# Dates                  0
# dtype: int64
# C:\Users\Фархат\AppData\Local\Temp\ipykernel_300\2040806283.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Salaries'].fillna(0,inplace = True)
# C:\Users\Фархат\AppData\Local\Temp\ipykernel_300\2040806283.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Educations'].fillna('Any',inplace = True)
# C:\Users\Фархат\AppData\Local\Temp\ipykernel_300\2040806283.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Fields'].fillna('No Field',inplace = True)
# C:\Users\Фархат\AppData\Local\Temp\ipykernel_300\2040806283.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Enrollment_statuses'].fillna('Unknown',inplace = True)

# %%
print(data.isnull().sum())
# Out:
# Titles                 0
# Fields                 0
# Salaries               0
# Locations              0
# Cities                 0
# Experiences            0
# Enrollment_statuses    0
# Educations             0
# Dates                  0
# dtype: int64

# %%
data
# Out:
#                                       Titles                     Fields  \
# 0    Тілдік пәндер саласындағы ЖОО оқытушысы  Білім беру және тәрбиелеу
# 1                         Ресепшн қызметкері        Тұру және тамақтану
# 2                          Сәулетші-дизайнер        Құрылыс және сәулет
# 3                               SMM-менеджер         Маркетинг және БАҚ
# 4                          Әкімшілік хатшысы           HR және хатшылық
# ..                                       ...                        ...
# 305                      Шетел тілі мұғалімі  Білім беру және тәрбиелеу
# 306                  Тіл мектебінің мұғалімі  Білім беру және тәрбиелеу
# 307                                   Заңгер                   No Field
# 308                  Іс қағаздарын жүргізуші           HR және хатшылық
# 309               Іс-шараларды ұйымдастырушы                     Туризм
#
#                       Salaries  \
# 0     от 95 000 до 150 000 тг.
# 1    от 100 000 до 180 000 тг.
# 2           100 000 тг. бастап
# 3           100 000 тг. бастап
# 4           100 000 тг. бастап
# ..                         ...
# 305                          0
# 306                          0
# 307          85 000 тг. бастап
# 308   от 85 000 до 100 000 тг.
# 309          85 000 тг. бастап
#
#                                              Locations  \
# 0    "Каспий өңірі "Болашақ" колледжі" Жауапкершілі...
# 1                                      The Smart Space
# 2         "QAZ07" жауапкершілігі шектеулі серіктестігі
# 3         "QAZ07" жауапкершілігі шектеулі серіктестігі
# 4         "QAZ07" жауапкершілігі шектеулі серіктестігі
# ..                                                 ...
# 305                             ИП Жансая Жанатбеккызы
# 306                                   ИП " Жамал А.Қ "
# 307  Қазақстан Республикасындағы "ҚМГ Қашаған Б.В."...
# 308  Шымкент қаласы білім басқармасының "№144 жалпы...
# 309  "BeStar Travel" жауапкершілігі шектеулі серікт...
#
#                               Cities        Experiences  \
# 0         Маңғыстау облысы, Ақтау қ.  3 жыл жұмыс өтілі
# 1           Шымкент қ., Тұран ауданы    Еңбек өтілі жоқ
# 2    Батыс Қазақстан облысы, Орал қ.    Еңбек өтілі жоқ
# 3    Батыс Қазақстан облысы, Орал қ.    Еңбек өтілі жоқ
# 4    Батыс Қазақстан облысы, Орал қ.    Еңбек өтілі жоқ
# ..                               ...                ...
# 305        Алматы  қ., Әуезов ауданы    Еңбек өтілі жоқ
# 306       Шымкент қ., Қаратау ауданы    Еңбек өтілі жоқ
# 307                        Астана қ.  2 жыл жұмыс өтілі
# 308       Шымкент қ., Қаратау ауданы  1 жыл жұмыс өтілі
# 309     Алматы  қ., Бостандық ауданы    Еңбек өтілі жоқ
#
#        Enrollment_statuses                                      Educations  \
# 0         толық жұмыс күні                                          жоғары
# 1                 ауысымды  жалпы орта (1 сыныптан 11/12 сыныптарға дейін)
# 2         толық жұмыс күні                          техникалық және кәсіби
# 3         толық жұмыс күні                          техникалық және кәсіби
# 4    толық емес жұмыс күні                          техникалық және кәсіби
# ..                     ...                                             ...
# 305                Unknown                          техникалық және кәсіби
# 306                Unknown  жалпы орта (1 сыныптан 11/12 сыныптарға дейін)
# 307       толық жұмыс күні                                          жоғары
# 308       толық жұмыс күні                                          жоғары
# 309  толық емес жұмыс күні  жалпы орта (1 сыныптан 11/12 сыныптарға дейін)
#
#                      Dates
# 0    26.10.2024 жарияланды
# 1    25.10.2024 жарияланды
# 2    25.10.2024 жарияланды
# 3    25.10.2024 жарияланды
# 4    25.10.2024 жарияланды
# ..                     ...
# 305  10.09.2024 жарияланды
# 306  10.09.2024 жарияланды
# 307  09.09.2024 жарияланды
# 308  06.09.2024 жарияланды
# 309  03.09.2024 жарияланды
#
# [310 rows x 9 columns]

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Titles               310 non-null    object
#  1   Fields               310 non-null    object
#  2   Salaries             310 non-null    object
#  3   Locations            310 non-null    object
#  4   Cities               310 non-null    object
#  5   Experiences          310 non-null    object
#  6   Enrollment_statuses  310 non-null    object
#  7   Educations           310 non-null    object
#  8   Dates                310 non-null    object
# dtypes: object(9)
# memory usage: 21.9+ KB
# None

# %%
# So Salaries column got some troubles, because it uses from and to strings. So we need to get rid of them

import re

def extract_mean(s):
    # Ensure the input is a string
    s = str(s)
    
    # Use regex to find all numbers in the string
    numbers = re.findall(r'\d+\s*\d*', s)
    
    # Remove spaces and convert to integers
    numbers = [int(num.replace(" ", "")) for num in numbers]
    
    # Determine what to return based on the number of extracted values
    if len(numbers) == 2:
        # Calculate mean if there are two numbers
        return sum(numbers) / len(numbers)
    elif len(numbers) == 1:
        # Return the single number if only one exists
        return numbers[0]
    else:
        # Return None if no numbers found
        return 0

# Apply the function to Salaries column
data['Salaries'] = data['Salaries'].apply(extract_mean)
data['Salaries'] = data['Salaries'].astype(int)
data['Experiences'] = data['Experiences'].apply(extract_mean)
data['Salaries'] = data['Salaries'].astype(int)


data['Dates'] = data['Dates'].str.extract(r'(\d{2}\.\d{2}\.\d{4})')
data['Cities'] = data['Cities'].str.split(',').str[0]

# %%
data
# Out:
#                                       Titles                     Fields  \
# 0    Тілдік пәндер саласындағы ЖОО оқытушысы  Білім беру және тәрбиелеу
# 1                         Ресепшн қызметкері        Тұру және тамақтану
# 2                          Сәулетші-дизайнер        Құрылыс және сәулет
# 3                               SMM-менеджер         Маркетинг және БАҚ
# 4                          Әкімшілік хатшысы           HR және хатшылық
# ..                                       ...                        ...
# 305                      Шетел тілі мұғалімі  Білім беру және тәрбиелеу
# 306                  Тіл мектебінің мұғалімі  Білім беру және тәрбиелеу
# 307                                   Заңгер                   No Field
# 308                  Іс қағаздарын жүргізуші           HR және хатшылық
# 309               Іс-шараларды ұйымдастырушы                     Туризм
#
#      Salaries                                          Locations  \
# 0      122500  "Каспий өңірі "Болашақ" колледжі" Жауапкершілі...
# 1      140000                                    The Smart Space
# 2      100000       "QAZ07" жауапкершілігі шектеулі серіктестігі
# 3      100000       "QAZ07" жауапкершілігі шектеулі серіктестігі
# 4      100000       "QAZ07" жауапкершілігі шектеулі серіктестігі
# ..        ...                                                ...
# 305         0                             ИП Жансая Жанатбеккызы
# 306         0                                   ИП " Жамал А.Қ "
# 307     85000  Қазақстан Республикасындағы "ҚМГ Қашаған Б.В."...
# 308     92500  Шымкент қаласы білім басқармасының "№144 жалпы...
# 309     85000  "BeStar Travel" жауапкершілігі шектеулі серікт...
#
#                      Cities  Experiences    Enrollment_statuses  \
# 0          Маңғыстау облысы            3       толық жұмыс күні
# 1                Шымкент қ.            0               ауысымды
# 2    Батыс Қазақстан облысы            0       толық жұмыс күні
# 3    Батыс Қазақстан облысы            0       толық жұмыс күні
# 4    Батыс Қазақстан облысы            0  толық емес жұмыс күні
# ..                      ...          ...                    ...
# 305              Алматы  қ.            0                Unknown
# 306              Шымкент қ.            0                Unknown
# 307               Астана қ.            2       толық жұмыс күні
# 308              Шымкент қ.            1       толық жұмыс күні
# 309              Алматы  қ.            0  толық емес жұмыс күні
#
#                                          Educations       Dates
# 0                                            жоғары  26.10.2024
# 1    жалпы орта (1 сыныптан 11/12 сыныптарға дейін)  25.10.2024
# 2                            техникалық және кәсіби  25.10.2024
# 3                            техникалық және кәсіби  25.10.2024
# 4                            техникалық және кәсіби  25.10.2024
# ..                                              ...         ...
# 305                          техникалық және кәсіби  10.09.2024
# 306  жалпы орта (1 сыныптан 11/12 сыныптарға дейін)  10.09.2024
# 307                                          жоғары  09.09.2024
# 308                                          жоғары  06.09.2024
# 309  жалпы орта (1 сыныптан 11/12 сыныптарға дейін)  03.09.2024
#
# [310 rows x 9 columns]

# %%
# It is possible that it may got some duplicates, because one employer can put a lot of vacancies to attract more people
print(data.duplicated().sum())
data = data.drop_duplicates()
# Out:
# 9

# %%
print(data.duplicated().sum())
# Out:
# 0

# %%
# EDA

#Standard deviation of salaries per city
std_salary_by_city = data.groupby('Cities')['Salaries'].std().sort_values(ascending=False)

# Salary based on field
avg_salary_by_field = data.groupby('Fields')['Salaries'].mean().sort_values(ascending=False)

# Number of jobs by Fields
count_field = data['Fields'].value_counts()

# Number of jobs based on Date
count_jobs_by_date = data.groupby('Dates')['Titles'].count().sort_values(ascending=False)

# Median Salary based on City
avg_exp_by_city = data.groupby('Cities')['Experiences'].median().sort_values(ascending=False)

# Avg Salary based on Education
median_salary_by_education = data.groupby('Educations')['Salaries'].mean().sort_values(ascending=False)

#Avg Salary based on Experience
title_count_by_location = data.groupby('Experiences')['Salaries'].mean().sort_values(ascending=False)

# Using pivot table to analyze salary based on Education and Enrollment_statuses
salary_pivot_ed_enr = pd.pivot_table(data, values='Salaries', index='Educations', columns='Enrollment_statuses', aggfunc='mean',fill_value = 0)


correlation_matrix = data[['Salaries','Experiences']].corr()

fields_locations = pd.crosstab(data['Educations'], data['Experiences'])


print(std_salary_by_city)
print(avg_salary_by_field)
print(count_field)
print(count_jobs_by_date)
print(avg_salary_by_city)
print(median_salary_by_education)
print(title_count_by_location)
print(fields_locations)
# Out:
# Cities
# Қарағанды облысы          223450.232212
# Атырау облысы             199323.599556
# Астана қ.                 191881.316255
# Абай облысы               176376.945965
# Ұлытау облысы             162702.097172
# Алматы  қ.                146286.377942
# Маңғыстау облысы          111753.203127
# Алматы облысы             105987.420637
# Ақтөбе облысы             104223.736717
# Шымкент қ.                 89924.745323
# Ақмола облысы              88211.393822
# Түркістан облысы           86602.540378
# Шығыс Қазақстан облысы     85401.014826
# Батыс Қазақстан облысы     76604.367804
# Жетісу облысы              60484.157705
# Жамбыл облысы              54270.280086
# Қостанай облысы            42779.960262
# Павлодар облысы            35882.001059
# Name: Salaries, dtype: float64
# Fields
# Басшылар                          525954.545455
# Көлік және логистика              436644.000000
# Мұнай, газ, ресурстарды өндіру    435000.000000
# Жеке қызметтер және сервис        396250.000000
# Қаржы және бухгалтерлік есеп      375000.000000
# IT және телекоммуникациялар       370131.578947
# Ғылым және кеңес беру             322207.333333
# Ауыл шаруашылығы                  300000.000000
# Қауіпсіздік және ТЖ               300000.000000
# Сауда және қоймалау               285454.545455
# Маркетинг және БАҚ                278833.333333
# Құрылыс және сәулет               244800.000000
# Өндіріс                           230416.666667
# HR және хатшылық                  229318.181818
# Медицина және фармацевтика        227490.000000
# Құқықтану                         222976.000000
# Білім беру және тәрбиелеу         206250.406250
# Тұру және тамақтану               185000.000000
# Мәдениет және спорт               158121.125000
# Мемлекеттік қызмет                145000.000000
# Біліктілігі жоқ мамандықтар       119818.250000
# Туризм                            116666.666667
# ТКШ және абаттандыру               95000.000000
# Әлеуметтік қызмет көрсету          92500.000000
# No Field                           85000.000000
# Name: Salaries, dtype: float64
# Fields
# Білім беру және тәрбиелеу         96
# Көлік және логистика              25
# HR және хатшылық                  22
# Медицина және фармацевтика        20
# IT және телекоммуникациялар       19
# Ғылым және кеңес беру             18
# Қаржы және бухгалтерлік есеп      16
# Маркетинг және БАҚ                12
# Өндіріс                           12
# Сауда және қоймалау               11
# Басшылар                          11
# Мұнай, газ, ресурстарды өндіру     8
# Мәдениет және спорт                8
# Құрылыс және сәулет                5
# Құқықтану                          5
# Біліктілігі жоқ мамандықтар        4
# Тұру және тамақтану                4
# No Field                           4
# Туризм                             3
# Жеке қызметтер және сервис         2
# ТКШ және абаттандыру               1
# Қауіпсіздік және ТЖ                1
# Мемлекеттік қызмет                 1
# Ауыл шаруашылығы                   1
# Әлеуметтік қызмет көрсету          1
# Name: count, dtype: int64
# Dates
# 21.10.2024    51
# 14.10.2024    42
# 10.10.2024    23
# 18.10.2024    22
# 17.10.2024    20
# 24.10.2024    19
# 22.10.2024    17
# 02.10.2024    15
# 23.10.2024    15
# 01.10.2024    12
# 11.10.2024    12
# 04.10.2024     9
# 08.10.2024     8
# 16.10.2024     7
# 15.10.2024     7
# 03.10.2024     6
# 07.10.2024     5
# 25.10.2024     4
# 30.09.2024     4
# 09.10.2024     3
# 10.09.2024     2
# 09.09.2024     1
# 20.10.2024     1
# 06.09.2024     1
# 03.09.2024     1
# 25.09.2024     1
# 26.10.2024     1
# 27.09.2024     1
# Name: Titles, dtype: int64
# Cities
# Астана қ.                 370000.0
# Атырау облысы             280000.0
# Түркістан облысы          250000.0
# Маңғыстау облысы          235000.0
# Жамбыл облысы             207500.0
# Қостанай облысы           205250.0
# Шығыс Қазақстан облысы    202500.0
# Абай облысы               200000.0
# Ақмола облысы             200000.0
# Ұлытау облысы             190000.0
# Алматы  қ.                180000.0
# Алматы облысы             175000.0
# Батыс Қазақстан облысы    150000.0
# Қарағанды облысы          150000.0
# Жетісу облысы             135000.0
# Шымкент қ.                117250.0
# Ақтөбе облысы             110000.0
# Павлодар облысы            85000.0
# Name: Salaries, dtype: float64
# Educations
# жоғары оқу орыннан кейін                          321640.000000
# жоғары                                            298072.915556
# техникалық және кәсіби                            194302.950000
# жалпы орта (1 сыныптан 11/12 сыныптарға дейін)    177812.500000
# ортадан кейін                                     132435.562500
# Any                                                85000.000000
# Name: Salaries, dtype: float64
# Experiences
# 10    612142.857143
# 7     571428.571429
# 6     502300.000000
# 4     367500.000000
# 5     334078.571429
# 3     290048.097561
# 8     280000.000000
# 2     255687.366667
# 0     182356.236111
# 1     168709.979167
# Name: Salaries, dtype: float64
# Experiences                                     0   1   2   3   4   5   6   \
# Educations
# Any                                              0   0   0   0   0   1   0
# жалпы орта (1 сыныптан 11/12 сыныптарға дейін)   5   2   0   0   1   0   0
# жоғары                                          35  31  27  65   5  39   3
# жоғары оқу орыннан кейін                         1   3   1   7   0   2   0
# ортадан кейін                                   11   5   0   0   0   0   0
# техникалық және кәсіби                          20   7   2  10   0   0   1
#
# Experiences                                     7   8   10
# Educations
# Any                                              0   0   0
# жалпы орта (1 сыныптан 11/12 сыныптарға дейін)   0   0   0
# жоғары                                           7   1  12
# жоғары оқу орыннан кейін                         0   4   2
# ортадан кейін                                    0   0   0
# техникалық және кәсіби                           0   0   0

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['Salaries'], bins=30, kde=True)
plt.title('Salary Distribution')
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(y='Fields', data=data, order=count_field.index)
plt.title('Count of Fields')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x='Salaries', y='Fields', data=data)
plt.title('Salaries by Field')
plt.show()

# %%
plt.figure(figsize=(12, 6))
avg_exp_by_city.plot(kind='barh', color='coral')
plt.title('Average Exp by City')
plt.xlabel('Average Exp')
plt.ylabel('City')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(fields_locations, annot=True, fmt='d', cmap='viridis', linewidths=0.5)
plt.title('Fields vs. Locations')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Matrix')
plt.show()
